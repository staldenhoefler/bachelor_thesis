# %%
from src.data.sika import CustomImageDataset
from torch.utils.data import DataLoader
from torchvision import transforms
import torch
import os

os.chdir('../..')

# %%
# Define the transformations
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Create the dataset
dataset = CustomImageDataset(
    data_path='./data/train',
    transform=transform
)
# Out:
# Error loading image Image_FHNW_00517.jpg

# %%
dataset.labels
# Out:
# [array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([4]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([3]),
#  array([3]),
#  array([5]),
#  array([2]),
#  array([3]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([2]),
#  array([2]),
#  array([3]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([3]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([2]),
#  array([3]),
#  array([4]),
#  array([5]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([4]),
#  array([2]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([4]),
#  array([3]),
#  array([3]),
#  array([3]),
#  array([3]),
#  array([5]),
#  array([2]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([3]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([2]),
#  array([2]),
#  array([2]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([4]),
#  array([4]),
#  array([4]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([3]),
#  array([5]),
#  array([5]),
#  array([2]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([3]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([2]),
#  array([2]),
#  array([2]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([2]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([2]),
#  array([4]),
#  array([3]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([3]),
#  array([1]),
#  array([4]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([2]),
#  array([2]),
#  array([2]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([3]),
#  array([3]),
#  array([4]),
#  array([4]),
#  array([1]),
#  array([2]),
#  array([3]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([3]),
#  array([4]),
#  array([5]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([2]),
#  array([2]),
#  array([5]),
#  array([3]),
#  array([4]),
#  array([1]),
#  array([2]),
#  array([3]),
#  array([5]),
#  array([4]),
#  array([4]),
#  array([3]),
#  array([5]),
#  array([1]),
#  array([3]),
#  array([1]),
#  array([4]),
#  array([3]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([4]),
#  array([1]),
#  array([3]),
#  array([2]),
#  array([4]),
#  array([1]),
#  array([4]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([2]),
#  array([5]),
#  array([2]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([5]),
#  array([1]),
#  array([1]),
#  array([2]),
#  array([1]),
#  array([5])]

# %%
# Create the DataLoader
dataloader = DataLoader(
    dataset,
    batch_size=4,
    shuffle=True,
    num_workers=0
)

batch = dataloader.__iter__().__next__()

# %%
batch
# Out:
# [tensor([[[[0.1529, 0.1608, 0.1647,  ..., 0.1373, 0.1490, 0.1373],
#            [0.1529, 0.1333, 0.1451,  ..., 0.1412, 0.1412, 0.1294],
#            [0.1647, 0.1451, 0.1490,  ..., 0.1412, 0.1333, 0.1412],
#            ...,
#            [0.0000, 0.0000, 0.0078,  ..., 0.0275, 0.0078, 0.0353],
#            [0.0000, 0.0039, 0.0157,  ..., 0.0549, 0.0431, 0.0392],
#            [0.0196, 0.0000, 0.0157,  ..., 0.0706, 0.0941, 0.0431]],
#
#           [[0.1725, 0.1804, 0.1843,  ..., 0.1569, 0.1647, 0.1529],
#            [0.1725, 0.1569, 0.1647,  ..., 0.1608, 0.1569, 0.1451],
#            [0.1843, 0.1647, 0.1686,  ..., 0.1608, 0.1490, 0.1569],
#            ...,
#            [0.0078, 0.0157, 0.0353,  ..., 0.0353, 0.0118, 0.0392],
#            [0.0157, 0.0235, 0.0471,  ..., 0.0627, 0.0510, 0.0471],
#            [0.0353, 0.0157, 0.0431,  ..., 0.0784, 0.1020, 0.0549]],
#
#           [[0.1765, 0.1843, 0.1882,  ..., 0.1686, 0.1843, 0.1725],
#            [0.1765, 0.1569, 0.1686,  ..., 0.1725, 0.1765, 0.1647],
#            [0.1882, 0.1686, 0.1725,  ..., 0.1725, 0.1686, 0.1765],
#            ...,
#            [0.0000, 0.0078, 0.0235,  ..., 0.0392, 0.0235, 0.0510],
#            [0.0078, 0.0157, 0.0353,  ..., 0.0627, 0.0549, 0.0510],
#            [0.0314, 0.0078, 0.0314,  ..., 0.0784, 0.1020, 0.0588]]],
#
#
#          [[[0.4157, 0.4235, 0.4275,  ..., 0.4549, 0.4627, 0.4549],
#            [0.4118, 0.4157, 0.4275,  ..., 0.4510, 0.4588, 0.4549],
#            [0.4078, 0.4157, 0.4235,  ..., 0.4549, 0.4588, 0.4588],
#            ...,
#            [0.4039, 0.4078, 0.4078,  ..., 0.5020, 0.5176, 0.5137],
#            [0.3922, 0.3961, 0.4039,  ..., 0.5098, 0.5255, 0.5176],
#            [0.3922, 0.4000, 0.4039,  ..., 0.5020, 0.5137, 0.5216]],
#
#           [[0.4353, 0.4431, 0.4471,  ..., 0.4745, 0.4824, 0.4784],
#            [0.4314, 0.4392, 0.4431,  ..., 0.4706, 0.4784, 0.4784],
#            [0.4275, 0.4353, 0.4431,  ..., 0.4745, 0.4784, 0.4824],
#            ...,
#            [0.4314, 0.4353, 0.4353,  ..., 0.5255, 0.5412, 0.5373],
#            [0.4196, 0.4235, 0.4314,  ..., 0.5294, 0.5490, 0.5412],
#            [0.4157, 0.4235, 0.4275,  ..., 0.5255, 0.5373, 0.5451]],
#
#           [[0.4314, 0.4392, 0.4431,  ..., 0.4706, 0.4784, 0.4745],
#            [0.4275, 0.4353, 0.4392,  ..., 0.4667, 0.4745, 0.4745],
#            [0.4235, 0.4314, 0.4392,  ..., 0.4706, 0.4745, 0.4784],
#            ...,
#            [0.4431, 0.4471, 0.4471,  ..., 0.5451, 0.5608, 0.5569],
#            [0.4314, 0.4353, 0.4431,  ..., 0.5490, 0.5686, 0.5608],
#            [0.4353, 0.4431, 0.4471,  ..., 0.5451, 0.5569, 0.5647]]],
#
#
#          [[[0.0627, 0.0667, 0.0667,  ..., 0.0549, 0.0549, 0.0588],
#            [0.0588, 0.0667, 0.0667,  ..., 0.0549, 0.0549, 0.0588],
#            [0.0588, 0.0627, 0.0667,  ..., 0.0549, 0.0549, 0.0588],
#            ...,
#            [0.1490, 0.1451, 0.1608,  ..., 0.1412, 0.1373, 0.1333],
#            [0.1451, 0.1490, 0.1412,  ..., 0.1294, 0.1255, 0.1176],
#            [0.1216, 0.1529, 0.1412,  ..., 0.1373, 0.1216, 0.1216]],
#
#           [[0.4588, 0.4627, 0.4627,  ..., 0.4471, 0.4471, 0.4510],
#            [0.4549, 0.4627, 0.4627,  ..., 0.4471, 0.4471, 0.4510],
#            [0.4549, 0.4588, 0.4627,  ..., 0.4471, 0.4471, 0.4510],
#            ...,
#            [0.6118, 0.6078, 0.6235,  ..., 0.6000, 0.5961, 0.5922],
#            [0.6078, 0.6118, 0.6039,  ..., 0.5882, 0.5843, 0.5765],
#            [0.5843, 0.6157, 0.6039,  ..., 0.5961, 0.5843, 0.5804]],
#
#           [[0.5569, 0.5608, 0.5608,  ..., 0.5412, 0.5412, 0.5451],
#            [0.5529, 0.5608, 0.5608,  ..., 0.5412, 0.5412, 0.5451],
#            [0.5529, 0.5569, 0.5608,  ..., 0.5412, 0.5412, 0.5451],
#            ...,
#            [0.7255, 0.7216, 0.7373,  ..., 0.7059, 0.7059, 0.6980],
#            [0.7216, 0.7255, 0.7216,  ..., 0.6941, 0.6902, 0.6824],
#            [0.6980, 0.7294, 0.7216,  ..., 0.7020, 0.6863, 0.6863]]],
#
#
#          [[[0.7608, 0.7608, 0.7608,  ..., 0.7451, 0.7451, 0.7451],
#            [0.7608, 0.7608, 0.7608,  ..., 0.7451, 0.7451, 0.7451],
#            [0.7608, 0.7608, 0.7608,  ..., 0.7451, 0.7451, 0.7451],
#            ...,
#            [0.6000, 0.6000, 0.6000,  ..., 0.5333, 0.5255, 0.5216],
#            [0.6078, 0.6078, 0.6039,  ..., 0.5451, 0.5373, 0.5333],
#            [0.6157, 0.6118, 0.6078,  ..., 0.5529, 0.5451, 0.5412]],
#
#           [[0.8275, 0.8275, 0.8275,  ..., 0.8196, 0.8196, 0.8196],
#            [0.8275, 0.8275, 0.8275,  ..., 0.8196, 0.8196, 0.8196],
#            [0.8275, 0.8275, 0.8275,  ..., 0.8196, 0.8196, 0.8196],
#            ...,
#            [0.6235, 0.6235, 0.6235,  ..., 0.5804, 0.5725, 0.5686],
#            [0.6314, 0.6314, 0.6275,  ..., 0.5922, 0.5843, 0.5804],
#            [0.6392, 0.6353, 0.6314,  ..., 0.6000, 0.5922, 0.5882]],
#
#           [[0.8784, 0.8784, 0.8784,  ..., 0.8706, 0.8706, 0.8706],
#            [0.8784, 0.8784, 0.8784,  ..., 0.8706, 0.8706, 0.8706],
#            [0.8784, 0.8784, 0.8784,  ..., 0.8706, 0.8706, 0.8706],
#            ...,
#            [0.6196, 0.6196, 0.6196,  ..., 0.5961, 0.5882, 0.5843],
#            [0.6314, 0.6275, 0.6235,  ..., 0.6078, 0.6000, 0.5961],
#            [0.6353, 0.6314, 0.6275,  ..., 0.6157, 0.6078, 0.6039]]]]),
#  tensor([1, 1, 5, 1])]
